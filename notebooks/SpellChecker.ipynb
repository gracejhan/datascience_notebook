# %% [markdown]
# Introduction to Data Science Homework 3: Spelling Checker Kaggle Competition
#
# Team: Jungwoo Han, Ting-Lan Wang
#
# Submission Date: March 10, 2018

# %%
import re
import numpy as np
import itertools
from collections import Counter
import string
import operator
import pandas as pd
import nltk

# create a dictionary 'ERRORS_DICT' of key=correct-word and value=misspelled-word
ERRORS_DICT = {}
letters = 'abcdefghijklmnopqrstuvwxyz'

#we use re package to filter out unnecessary characters, tokenize the words and convert it to lower case
def tokens(text):
    return re.findall('[a-z]+', text.lower()) 

def errors():
    with open('spell-errors.txt') as filestream:
        for line in filestream:
            value_list = []
            currentline = line.split(':')
            # key is the correct-word
            key = currentline[0].strip().lower()
            # if there is only one value
            if ',' not in currentline[1]:
                # if value is not a correctly-spelled word
                if currentline[1].strip().lower() != key:
                    value_list.append(tokens(currentline[1].strip().lower())[0])
            # else if there are multiple values
            else:
                values = currentline[1].split(',')
                for v in values:
                    if v.strip().lower() != key:
                        value_list.append(tokens(v.strip().lower())[0])
            ERRORS_DICT[key] = value_list

# initialize the confusion matrices
DEL = np.zeros((26, 26))
INS = np.zeros((26, 26))
SUB = np.zeros((26, 26))
TRANS = np.zeros((26, 26))

# initialize a set where letter/letter pair will be stored
# these letter/letter pair will be used when counting their frequency in ERRORS_DICT
twoLetters = set()

# %%
ERRORS_DICT2 = {}
def errors2():
    with open('count_1w.txt') as filestream:
        for line in filestream:
            currentline = line.split('\t')
            ERRORS_DICT2[currentline[0]] = int(currentline[1])
            
errors2()           
# total_cnt = sum(ERRORS_DICT2.values())

# %%
def updateConfusionMatrices(correct, wrong):
    """
    correct == key
    wrong == value
    
    """
    
    splits = [(correct[:i], correct[i:]) for i in range(len(correct) + 1)]
    
    # for all correct words, create the four lists of misspelled words
    deletes = [L + R[1:] for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
    inserts = [L + c + R for L, R in splits for c in letters]
    
    # identify the index in which difference between the two words(correct and wrong) occur
    
    # check which list the wrong word is included in
    if wrong in deletes:
        y_id = findDiff(correct, wrong)
        y = correct[y_id]
        x_id = y_id - 1
        x = correct[x_id]
        DEL[letters.find(x)][letters.find(y)] += 1
        twoLetters.add(x+y)
    
    elif wrong in inserts:
        y_id = findDiff(correct, wrong)
        y = wrong[y_id]
        x_id = y_id - 1
        x = wrong[x_id]
        INS[letters.find(x)][letters.find(y)] += 1
    
    elif wrong in replaces:
        y_id = findDiff(correct, wrong)
        y = correct[y_id]
        x_id = y_id
        x = wrong[x_id]
        SUB[letters.find(x)][letters.find(y)] += 1
    
    elif wrong in transposes:
        y_id = findDiff(correct, wrong)
        y = wrong[y_id]
        x_id = y_id + 1
        x = wrong[x_id]
        TRANS[letters.find(x)][letters.find(y)] += 1
        twoLetters.add(x + y)

# %%
def findDiff(correct, wrong):
    indices = []
    if correct != wrong:
        if len(correct) == len(wrong):
            for i in range(len(correct)):
                if correct[i] != wrong[i]:
                    indices.append(i)
        elif len(correct) != len(wrong):
            if len(correct) > len(wrong):
                long = correct
                short = wrong
            else:
                long = wrong
                short = correct
            for i in range(len(short)):
                size = len(short)
                if short == wrong[:size]:
                    indices.append(size)
                else:
                    for j in range(len(short)):
                        if short[j] != long[j]:
                            indices.append(j)   
    else:
        indices.append(-1)
    return indices[0]

# %%
def createConfusionMatrices():
    for key in ERRORS_DICT.keys():
        for value in ERRORS_DICT[key]:
            updateConfusionMatrices(key, value)


def getInitialCounter():
    counter = {}
    alphabets = set(string.ascii_lowercase)
    myset = alphabets.union(twoLetters)
    # iterate through the misspelled words LIST in ERRORS_DICT
    for valueList in ERRORS_DICT.values():
        # iterate through misspelled WORD in the LIST
        for word in valueList:
            # iterate through each LETTER of the WORD
            for c in word:
                # if c is in myset
                if c in myset:
                    # if the LETTER is already in the dictionary
                    if c in counter.keys():
                        counter[c] += 1
                    else:
                        counter[c] = 1
                    
            # iterate through each TWOLETTER of the WORD
            for i in range(len(word)-1):
                c1 = word[i]
                c2 = word[i+1]
                letters = c1 + c2
                if letters in myset:
                    if letters in counter.keys():
                        counter[letters] += 1
                    else:
                        counter[letters] = 1   
    return counter


def getCount(char):
    if char in counter.keys():
        return counter[char]
    else:
        for valueList in ERRORS_DICT.values():
            for value in valueList:
                if char in counter.keys():
                    counter[char] += value.count(char)
                else:
                    counter[char] = value.count(char)
        return counter[char]


def words(text): return re.findall(r'\w+', text.lower())

# %%
# frequency of words are checked on 'big.txt' file
WORDS = Counter(words(open('big.txt').read()))

# %%
def P(word, N=sum(WORDS.values())):
    "Probability of `word`."
    return WORDS[word] / N

def P2(word):
    return ERRORS_DICT2[word] / total_cnt

# %%
def edits1(word):
    "All edits that are one edit away from `word`."
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [L + R[1:] for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
    inserts = [L + c + R for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    return {e2 for e1 in edits1(word) for e2 in edits1(e1)}

def edits3(word):
    return {e2 for e1 in edits2(word) for e2 in edits2(e1)}

def edits4(word):
    return {e2 for e1 in edits3(word) for e2 in edits3(e1)}

# %%
def FromEdit2(word):
    words = edits2(word)
    dic = {}
    for w in words:
        if w in ERRORS_DICT.keys():
            dic[w] = P(w)
    return dic

def FromEdit3(word):
    words = edits3(word)
    dic = {}
    for w in words:
        if w in ERRORS_DICT.keys():
            dic[w] = P(w)
    return dic

def FromEdit4(word):
    words = edits4(word)
    dic = {}
    for w in words:
        if w in ERRORS_DICT.keys():
            dic[w] = P(w)
    return dic

# %%
def getDelP(wrong):
    # Try deleting a letter from the wrong word to get a correct word
    splits = [(wrong[:i], wrong[i:]) for i in range(len(wrong) + 1)]
    deletes = [L + R[1:] for L, R in splits if R]
    dic = {}
    for delete in deletes:
        # if the created word is a real word
        if delete in ERRORS_DICT.keys():
            y_id = findDiff(delete, wrong)
            x_id = y_id - 1
            y = wrong[y_id]
            x = wrong[x_id]
            # numerator comes from the confusion matrix
            num = INS[letters.find(x)][letters.find(y)]
            # divide it by the frequency of x
            den = getCount(x)
            dic[delete] = (num/den) * P(delete)
    return dic

def getInsP(wrong):
    # Try inserting a letter to the wrong word to get a correct word
    splits = [(wrong[:i], wrong[i:]) for i in range(len(wrong) + 1)]
    inserts = [L + c + R for L, R in splits for c in letters]
    dic = {}
    for insert in inserts:
        if insert in ERRORS_DICT.keys():
            # letter y has been deleted after x
            y_id = findDiff(insert, wrong)
            y = insert[y_id]
            x_id = y_id - 1
            x = insert[x_id]
            
            num = DEL[letters.find(x)][letters.find(y)]
            den = getCount(x+y)
            dic[insert] = (num/den) * P(insert)
    return dic

def getSubP(wrong):
    # Try substituting a letter in the wrong word to get a correct word
    splits = [(wrong[:i], wrong[i:]) for i in range(len(wrong) + 1)]
    subs = [L + c + R[1:] for L, R in splits if R for c in letters]
    dic = {}
    for sub in subs:
        if sub in ERRORS_DICT.keys():
            x_id = findDiff(sub, wrong)
            y_id = findDiff(sub, wrong)
            x = wrong[x_id]
            y = sub[y_id]
            num = SUB[letters.find(x)][letters.find(y)]
            den = getCount(y)
            dic[sub] = (num/den) * P(sub)
    return dic

def getTransP(wrong):
    # Try transposing two consecutive letters in the wrong word to get a correct word
    splits = [(wrong[:i], wrong[i:]) for i in range(len(wrong) + 1)]
    trans = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
    dic = {}
    for tran in trans:
        if tran in ERRORS_DICT.keys():
            y_id = findDiff(tran, wrong)
            x_id = y_id + 1
            y = wrong[y_id]
            x = wrong[x_id]
            num = TRANS[letters.find(x)][letters.find(y)]
            den = getCount(x+y)
            dic[tran] = (num/den) * P(tran)
    return dic

# %%
# initialize the ERRORS_DICT from training set
errors()
# train confusion matrices
createConfusionMatrices()
# count the frequencies of letter/two letters in our training set
counter = getInitialCounter()

# %% [markdown]
# Test code with inputs from CSV file

# %%
# read test input from csv file
spell_test = pd.read_csv('test.csv')

# save column names to col_names_test
col_names_test = spell_test.columns.tolist()

# remove rows which have NaN values
spell_test.dropna(how='any', inplace=True)

# drop the ID column
spell_test_words = spell_test.drop('ID', 1)

# spell_test_words.head()

# %%
# create a list of wrong words
wrong_list = []
for index, row in spell_test_words.iterrows():
    wrong_word = row['WRONG']
    wrong_list.append(wrong_word)
    
# print(wrong_list[:20])

# %%
# iterate through the wrong list, get the correct word, append it to a list

corrected_list = []

for i in range(len(wrong_list)):
    input_word = wrong_list[i]
    print(input_word)
    
    # Check if input_word is inside ERRORS_DICT
    corrects = []
    for k in ERRORS_DICT:
        value_list = ERRORS_DICT[k]
        if input_word in value_list:
            corrects.append(k)
    # If input_word is in the dictionary only once
    if(len(corrects)==1):
        result_word = corrects[0]
    # If input_word is not in the dictionary or there are multiples
    else:
        # If input_word itself is a correct word
        if (input_word in ERRORS_DICT.keys()):
            result_word = input_word
        # If not, predict from edit distance 1
        else:
            DelDict = getDelP(input_word)
            InsDict = getInsP(input_word)
            SubDict = getSubP(input_word)
            TranDict = getTransP(input_word)

            # combine all dictionaries into one
            CombDict = {**DelDict, **InsDict, **SubDict, **TranDict}

            # If edit distance 1 did not work try edit distance 2
            if bool(CombDict) == False:
                Edit2Dict = FromEdit2(input_word)
                if bool(Edit2Dict) == False:
                    Edit3Dict = FromEdit3(input_word)
                    if bool(Edit3Dict) == False:
                        result_word = 'NULL'
                    else:
                        result_word = max(Edit3Dict.items(), key=operator.itemgetter(1))[0]
                else:
                    result_word = max(Edit2Dict.items(), key=operator.itemgetter(1))[0]
            else:
                result_word = max(CombDict.items(), key=operator.itemgetter(1))[0]
    print("Result is: " + result_word)
    corrected_list.append(result_word)

# save the ouput to a CSV file
np.savetxt("prediction_jh5990_tlw355.csv",corrected_list, fmt="%s", delimiter=",", newline='\n')
# Out:
# contenpted
# Result is: contented
# begining
# Result is: beginning
# problam
# Result is: problem
# dirven
# Result is: driven
# exstacy
# Result is: ecstasy
# guic
# Result is: juice
# localy
# Result is: locally
# compair
# Result is: compare
# pronounciation
# Result is: pronunciation
# transportibility
# Result is: transportability
# miniscule
# Result is: minuscule
# independant
# Result is: independent
# aranged
# Result is: arranged
# poartry
# Result is: poetry
# leval
# Result is: level
# basicaly
# Result is: basically
# triangulaur
# Result is: triangular
# unexpcted
# Result is: unexpected
# stanerdizing
# Result is: standardizing
# varable
# Result is: variable
# futher
# Result is: further
# monitering
# Result is: monitoring
# biscits
# Result is: biscuits
# avaible
# Result is: available
# seperate
# Result is: separate
# neccesary
# Result is: necessary
# defenition
# Result is: definition
# receit
# Result is: receipt
# remine
# Result is: remind
# inetials
# Result is: initials
# magnificnet
# Result is: magnificent
# annt
# Result is: aunt
# intial
# Result is: initial
# ther
# Result is: the
# experances
# Result is: experiences
# biult
# Result is: built
# totaly
# Result is: totally
# undersand
# Result is: understand
# southen
# Result is: southern
# definately
# Result is: definitely
# fisited
# Result is: visited
# volantry
# Result is: voluntary
# ment
# Result is: meant
# recieve
# Result is: receive
# sorces
# Result is: sources
# wether
# Result is: whether
# usefull
# Result is: useful
# litriture
# Result is: literature
# valubale
# Result is: valuable
# desicate
# Result is: delicate
# clearical
# Result is: clerical
# spledid
# Result is: splendid
# beetween
# Result is: between
# completly
# Result is: completely
# acount
# Result is: account
# cemetary
# Result is: cemetery
# speaical
# Result is: special
# lates
# Result is: latest
# perhapse
# Result is: perhaps
# rember
# Result is: remember
# chaper
# Result is: chapter
# cak
# Result is: cake
# vairious
# Result is: various
# febuary
# Result is: february
# pertend
# Result is: pretend
# chosing
# Result is: choosing
# rote
# Result is: wrote
# particulaur
# Result is: particular
# awfall
# Result is: awful
# arragment
# Result is: arrangement
# chalenges
# Result is: challenges
# lagh
# Result is: laugh
# ofen
# Result is: often
# somone
# Result is: someone
# personnell
# Result is: personnel
# uneque
# Result is: unique
# diagrammaticaally
# Result is: diagrammatically
# discription
# Result is: description
# poims
# Result is: poems
# perple
# Result is: purple
# descide
# Result is: decide
# articals
# Result is: articles
# possition
# Result is: position
# extented
# Result is: extended
# hierachial
# Result is: hierarchical
# realy
# Result is: really
# voteing
# Result is: voting
# comittee
# Result is: committee
# wantid
# Result is: wanted
# benifits
# Result is: benefits
# defenitions
# Result is: definitions
# scisors
# Result is: scissors
# levals
# Result is: levels
# paralel
# Result is: parallel
# accomodation
# Result is: accommodation
# planed
# Result is: planted
# hierchy
# Result is: hierarchy
# transfred
# Result is: transferred
# muinets
# Result is: minutes
# aranging
# Result is: arranging
# accesing
# Result is: accessing
# stomac
# Result is: stomach
# unfortunatly
# Result is: unfortunately
# conciderable
# Result is: considerable
# acess
# Result is: access
# singulaur
# Result is: singular
# scarcly
# Result is: scarcely
# questionaire
# Result is: questionnaire
# experance
# Result is: experience
# possable
# Result is: possible
# reafreshment
# Result is: refreshment
# embaras
# Result is: embargo
# vistors
# Result is: visitors
# auxillary
# Result is: auxiliary
# descided
# Result is: decided
# benifit
# Result is: benefit
# concider
# Result is: consider
# failes
# Result is: fails
# carrer
# Result is: career
# occurence
# Result is: occurrence
# cirtain
# Result is: certain
# poame
# Result is: poems
# liew
# Result is: lieu
# astablishing
# Result is: establishing
# diffrent
# Result is: different
# lones
# Result is: lines
# extreamly
# Result is: extremely
# addresable
# Result is: addressable
# galery
# Result is: gallery
# centraly
# Result is: centrally
# familes
# Result is: families
# bicycal
# Result is: bicycle
# choise
# Result is: choice
# opisite
# Result is: opposite
# cartains
# Result is: curtains
# adress
# Result is: address
# liaision
# Result is: liaison
# managment
# Result is: management
# inconvienient
# Result is: inconvenient
# vairiant
# Result is: variant
# supercede
# Result is: supersede
# apeal
# Result is: appeal
# emploies
# Result is: employees
# encorage
# Result is: encourage
# perminant
# Result is: permanent
# mathematicaly
# Result is: mathematically
# dsata
# Result is: data
# perminantly
# Result is: permanently
# hierachial
# Result is: hierarchical
# provisoe
# Result is: proviso
# moveing
# Result is: moving
# alow
# Result is: allow
# creadit
# Result is: credit
# availble
# Result is: available
# traditionaly
# Result is: traditionally
# adabtable
# Result is: adaptable
# latter
# Result is: latter
# graphicaly
# Result is: graphically
# eventully
# Result is: eventually
# doupt
# Result is: doubt
# academicly
# Result is: academically
# subsequant
# Result is: subsequent
# missleading
# Result is: misleading
# ordenary
# Result is: ordinary
# assosiated
# Result is: associated
# volantary
# Result is: voluntary
# enomosly
# Result is: enormously
# tasble
# Result is: table
# usful
# Result is: useful
# thermawere
# Result is: thermawear
# plesent
# Result is: pleasant
# beeteen
# Result is: between
# apreciation
# Result is: appreciation
# acept
# Result is: accept
# suufering
# Result is: suffering
# comparrison
# Result is: comparison
# majorty
# Result is: majority
# umberalla
# Result is: umbrella
# disiplin
# Result is: discipline
# arrangment
# Result is: arrangement
# prepaired
# Result is: prepared
# suficient
# Result is: sufficient
# wagted
# Result is: weighted
# orentated
# Result is: orientated
# inut
# Result is: input
# pivting
# Result is: pivoting
# proffit
# Result is: profit
# agences
# Result is: agencies
# acumulated
# Result is: accumulated
# manualy
# Result is: manually
# representitive
# Result is: representative
# emploied
# Result is: employed
# contuned
# Result is: continued
# draged
# Result is: dragged
# unresloved
# Result is: unresolved
# comppared
# Result is: compared
# noe
# Result is: now
# anouncing
# Result is: announcing
# unequaled
# Result is: unequalled
# curruntly
# Result is: currently
# tittles
# Result is: titles
# reching
# Result is: reaching
# aproached
# Result is: approached
# sugestion
# Result is: suggestion
# avaiblity
# Result is: availability
# desention
# Result is: dissension
# cancelation
# Result is: cancellation
# trasactions
# Result is: transactions
# belive
# Result is: believe
# operatins
# Result is: operations
# reulting
# Result is: resulting
# descides
# Result is: decides
# unequivocaly
# Result is: unequivocally
# muinutes
# Result is: minutes
# understadable
# Result is: understandable
# dependance
# Result is: dependence
# supposidly
# Result is: supposedly
# subtrcat
# Result is: subtract
# sheertes
# Result is: sheets
# consisit
# Result is: consist
# imidatly
# Result is: immediately
# exponentualy
# Result is: exponentially
# overal
# Result is: overall
# indead
# Result is: indeed
# seperated
# Result is: separated
# lengh
# Result is: length
# familys
# Result is: families
# nessisitates
# Result is: necessitates
# discribed
# Result is: described
# pimarily
# Result is: primarily
# sugested
# Result is: suggested
# possablities
# Result is: possibilities
# biulding
# Result is: building
# universaly
# Result is: universally
# unessasarily
# Result is: unnecessarily
# begining
# Result is: beginning
# anf
# Result is: and
# coments
# Result is: comments
# thw
# Result is: the
# declaratrions
# Result is: declarations
# supervison
# Result is: supervision
# questionare
# Result is: questionnaire
# develope
# Result is: develop
# unavailble
# Result is: unavailable
# apointments
# Result is: appointments
# varible
# Result is: variable
# repetative
# Result is: repetitive
# equaled
# Result is: equalled
# bonas
# Result is: bonus
# diemands
# Result is: demands
# scrutiniesed
# Result is: scrutinized
# reciently
# Result is: recently
# cleark
# Result is: clerk
# adiquate
# Result is: adequate
# fealing
# Result is: feeling
# familer
# Result is: familiar
# acepted
# Result is: accepted
# accesing
# Result is: accessing
# seperation
# Result is: separation
# equiries
# Result is: inquiries
# recieving
# Result is: receiving
# proceduer
# Result is: procedure
# concieved
# Result is: conceived
# generataed
# Result is: generated
# flexable
# Result is: flexible
# analiss
# Result is: analysis
# particulary
# Result is: particularly
# rouint
# Result is: routine
# natior
# Result is: nature
# ganing
# Result is: gaining
# geniva
# Result is: geneva
# intresting
# Result is: interesting
# suroundings
# Result is: surroundings
# oppertunity
# Result is: opportunity
# functionaly
# Result is: functionally
# togehter
# Result is: together
# aproach
# Result is: approach
# scheem
# Result is: scheme
# occureed
# Result is: occurred
# preffeson
# Result is: profession
# recomend
# Result is: recommend
# examin
# Result is: examine
# thear
# Result is: there
# reajusted
# Result is: readjusted
# biuld
# Result is: build
# oranisation
# Result is: organization
# unversity
# Result is: university
# utalised
# Result is: utilized
# optaning
# Result is: obtaining
# comersial
# Result is: commercial
# embelishing
# Result is: embellishing
# desription
# Result is: description
# ediion
# Result is: edition
# forbiden
# Result is: forbidden
# aplicable
# Result is: applicable
# committe
# Result is: committee
# serch
# Result is: search
# nessesity
# Result is: necessity
# similar
# Result is: similar
# luckeley
# Result is: luckily
# economtric
# Result is: econometric
# agiin
# Result is: again
# pattarns
# Result is: patterns
# aalysing
# Result is: analysing
# variatry
# Result is: variety
# widly
# Result is: widely
# araingements
# Result is: arrangements
# chalange
# Result is: challenge
# forth
# Result is: fourth
# acounts
# Result is: accounts
# polatics
# Result is: politics
# descisions
# Result is: decisions
# sence
# Result is: sense
# benificial
# Result is: beneficial
# aurguing
# Result is: arguing
# contually
# Result is: continually
# aquantences
# Result is: acquaintances
# extreemly
# Result is: extremely
# exessively
# Result is: excessively
# compossed
# Result is: composed
# seeen
# Result is: seen
# nationaly
# Result is: nationally
# sorce
# Result is: source
# monthes
# Result is: months
# progressess
# Result is: progresses
# wer
# Result is: were
# brif
# Result is: brief
# matriiix
# Result is: matrix
# vistor
# Result is: visitor
# adequattly
# Result is: adequately
# seurity
# Result is: security
# sucsesive
# Result is: successive
# consisiting
# Result is: consisting
# pere
# Result is: per
# comit
# Result is: commit
# excxept
# Result is: except
# conversly
# Result is: conversely
# deciscions
# Result is: decisions
# unioun
# Result is: union
# whn
# Result is: when
# hown
# Result is: shown
# wil
# Result is: will
# suted
# Result is: suited
# necasery
# Result is: necessary
# esential
# Result is: essential
# goverment
# Result is: government
# unessessay
# Result is: unnecessary
# disaggreagte
# Result is: disaggregate
# aurgument
# Result is: argument
# choises
# Result is: choices
# conferance
# Result is: conference
# proceding
# Result is: proceeding
# proffits
# Result is: profits
# apparant
# Result is: apparent
# idealy
# Result is: ideally
# ablity
# Result is: ability
# responsiblities
# Result is: responsibilities
# arte
# Result is: are
# mony
# Result is: money
# servaying
# Result is: surveying
# provid
# Result is: provide
# withing
# Result is: within
# sesion
# Result is: session
# faulse
# Result is: false
# anual
# Result is: annual
# sumarys
# Result is: summaries
# refereence
# Result is: reference
# empolyment
# Result is: employment
# et
# Result is: it
# paerticulaur
# Result is: particular
# serounding
# Result is: surrounding
# chose
# Result is: chose
# journaism
# Result is: journalism
# anoying
# Result is: annoying
# expence
# Result is: expense
# recieve
# Result is: receive
# howeverr
# Result is: however
# suplementary
# Result is: supplementary
# vertually
# Result is: virtually
# forcast
# Result is: forecast
# heiarky
# Result is: hierarchy
# comibine
# Result is: combine
# rquested
# Result is: requested
# despratly
# Result is: desperately
# apreciated
# Result is: appreciated
# safegaurd
# Result is: safeguard
# shortend
# Result is: shortened
# confermation
# Result is: confirmation
# advantageos
# Result is: advantageous
# thees
# Result is: these
# befor
# Result is: before
# progresion
# Result is: progression
# componant
# Result is: component
# numbuers
# Result is: numbers
# adjurnment
# Result is: adjournment
# acording
# Result is: according
# oppinion
# Result is: opinion
# advice
# Result is: advise
# carear
# Result is: career
# resoved
# Result is: resolved
# accessability
# Result is: accessibility
# negligable
# Result is: negligible
# studens
# Result is: students
# faverable
# Result is: favourable
# tecniques
# Result is: techniques
# atmospher
# Result is: atmosphere
# exsactly
# Result is: exactly
# especaily
# Result is: especially
# proprtions
# Result is: proportions
# goegraphicaly
# Result is: geographically
# encompasing
# Result is: encompassing
# stoped
# Result is: stopped
# relavent
# Result is: relevant
# thay
# Result is: they
# upplied
# Result is: applied
# elimiated
# Result is: eliminated
# containg
# Result is: contain
# conditining
# Result is: conditioning
# sucssuful
# Result is: successful
# quies
# Result is: queries
# agravating
# Result is: aggravating
# errounous
# Result is: erroneous
# wepons
# Result is: weapons
# corparate
# Result is: corporate
# inconcievable
# Result is: inconceivable
# oranised
# Result is: organized
# sensable
# Result is: sensible
# studing
# Result is: studying
# eximination
# Result is: examination
# analiss
# Result is: analysis
# lonley
# Result is: lonely
# intrest
# Result is: interest
# comittees
# Result is: committees
# explaning
# Result is: explaining
# humor
# Result is: humour
# thorts
# Result is: thoughts
# timeing
# Result is: timing
# dificulty
# Result is: difficulty
# currers
# Result is: careers
# rgister
# Result is: register
# nite
# Result is: night
# appoitment
# Result is: appointment
# servays
# Result is: surveys
# appologies
# Result is: apologies
# aproximatly
# Result is: approximately
# throut
# Result is: through
# piror
# Result is: prior
# executted
# Result is: executed
# anomolies
# Result is: anomalies
# relativly
# Result is: relatively
# anouncement
# Result is: announcement
# acompaning
# Result is: accompanying
# projeccts
# Result is: projects
# analised
# Result is: analysed
# therefoe
# Result is: therefore
# perametres
# Result is: parameters
# wheras
# Result is: whereas
# ther
# Result is: the
# discresion
# Result is: discretion
# handel
# Result is: handle
# dissapoiting
# Result is: disappointing
# expanion
# Result is: expansion
# personel
# Result is: personal
# sienior
# Result is: senior
# appologised
# Result is: apologized
# seporate
# Result is: separate
# meen
# Result is: mean
# guidlines
# Result is: guidelines
# buisy
# Result is: busy
# easyly
# Result is: easily
# colate
# Result is: collate
# sysem
# Result is: system
# speeking
# Result is: speaking
# interogationg
# Result is: interrogating
# drasticaly
# Result is: drastically
# dificult
# Result is: difficult
# ineffiect
# Result is: inefficient
# opertor
# Result is: operator
# oputput
# Result is: output
# basse
# Result is: base
# regined
# Result is: regained
# controled
# Result is: controlled
# reffered
# Result is: referred
# irrelavent
# Result is: irrelevant
# athough
# Result is: although
# yesars
# Result is: years
# meens
# Result is: means
# tecnique
# Result is: technique
# niether
# Result is: neither
# reequired
# Result is: required
# correspondance
# Result is: correspondence
# interpritation
# Result is: interpretation
# segemnt
# Result is: segment
# throuout
# Result is: throughout
# quaties
# Result is: qualities
# financialy
# Result is: financially
# inteligence
# Result is: intelligence
# recives
# Result is: receives
# citisum
# Result is: criticism
# whould
# Result is: would
# investegated
# Result is: investigated
# recomending
# Result is: recommending
# earlyest
# Result is: earliest
# imediate
# Result is: immediate
